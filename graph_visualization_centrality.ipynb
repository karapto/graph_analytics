# %%
import networkx as nx
from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import numpy.linalg as LA
from pprint import pprint

# %%
uploaded = files.upload()

# %%
for fn in uploaded.keys():
  print("User uploaded file '{name}' with length {length} bytes".format(name=fn, length=len(uploaded[fn])))
  G = nx.readwrite.gml.read_gml(fn)
  nx.draw_spring(G, node_size=200, node_color="#00C98D", with_labels=True)
# Out:
# User uploaded file 'lesmis.gml' with length 17610 bytes

# %%
# plt.subplot(231)
# nx.draw_circular(G,node_size=40, node_color="#00C98D", with_labels=True)
# plt.subplot(232)
# nx.draw_kamada_kawai(G,node_size=10, node_color="#00C98D", with_labels=True)
# plt.subplot(233)
# nx.draw_random(G,node_size=10, node_color="#00C98D", with_labels=True)
# plt.subplot(234)
# nx.draw_spectral(G,node_size=10, node_color="#00C98D", with_labels=True)
# plt.subplot(235)
# nx.draw_spring(G,node_size=40, node_color="#00C98D", with_labels=True)
# plt.subplot(236)
# nx.draw_shell(G,node_size=40, node_color="#00C98D", with_labels=True)

# %%
def draw_heatmap(G, pos, measures, measure_name):
  nodes = nx.draw_networkx_nodes(G, pos, node_size=250,
                                 cmap = plt.cm.plasma,
                                 node_color = list(measures.values()),
                                 nodelist=list(measures.keys()))
  nodes.set_norm(mcolors.SymLogNorm(linthresh=0.01, linscale=1))
  edges = nx.draw_networkx_labels(G, pos)
  plt.title(measure_name)
  plt.colorbar(nodes)
  plt.axis("off")
  plt.show()

# %%
pos = nx.spring_layout(G)
draw_heatmap(G, pos, nx.degree_centrality(G), "Degree Centrality")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
pos = nx.spring_layout(G)
draw_heatmap(G, pos, nx.eigenvector_centrality(G), "Eigenvector Centrality")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
pos = nx.spring_layout(G)
draw_heatmap(G, pos, nx.closeness_centrality(G), "Closeness Centrality")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.

# %%
pos = nx.spring_layout(G)
draw_heatmap(G, pos, nx.betweenness_centrality(G), "Betweenness Centrality")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
